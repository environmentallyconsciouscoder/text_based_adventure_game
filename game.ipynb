# %%
graph = {
    'A': {'nodes': ['B', 'C'], 'direction': {'N': 'B', 'W': 'C', 'E': None, 'S': None}, 'questions': 'choose a direction'},
    'B': {'nodes': ['A'], 'direction': {'N': 'A', 'W': None, 'E': None, 'S': None}, 'questions': 'choose a direction'},
    'C': {'nodes': ['A', 'D', 'E', 'F'], 'direction': {'N': 'A', 'W': 'D', 'E': 'E', 'S': 'F'}, 'questions': 'choose a direction'},
    'D': {'nodes': ['C', 'G'], 'direction': {'N': 'C', 'W': 'G', 'E': None, 'S': None}, 'questions': 'choose a direction'},
    'E': {'nodes': ['C', 'G'], 'direction': {'N': 'C', 'W': 'G', 'E': None, 'S': None}, 'questions': 'choose a direction'},
    'G': {'nodes': ['E', 'D'], 'direction': {'N': 'E', 'W': 'D', 'E': None, 'S': None}, 'questions': 'choose a direction'},
    'F': {'nodes': [], 'direction': {'N': None, 'W': None, 'E': None, 'S': None}, 'questions': 'choose a direction'}
}

# def get_direction(user_input, node):
#     for direction in user_input:
#         print("node", node)
#         print("user_input", user_input)
#         if direction == 'N':
#             return graph[node]['direction'][direction]
#         elif direction == 'W':
#             return graph[node]['direction'][direction]
#         elif direction == 'S':
#             return graph[node]['direction'][direction]
#         elif direction == 'E':
#             return graph[node]['direction'][direction]
#         else:
#             print("Invalid direction entered")

def get_direction(user_input, node):
    for direction in user_input:
        print("node", node)
        print("user_input", user_input)
        if direction in graph[node]['direction']:
            return graph[node]['direction'][direction]

    print("Invalid direction entered")
    return None

def get_node(node='A'):
    print(node)
    # If the game hasn't reached the last node, keep playing
    while len(graph[node]['nodes']) != 0:

        user_input = input(graph[node]['questions'])
        print("user_input", user_input)
        next_node = get_direction(user_input, node)
        print(next_node)
        if next_node is not None:
            get_node(next_node)
        else:
            print(" direction does not exists. Try again.")
            continue
        break
    if len(graph[node]['nodes']) == 0:
        print("You won")
        end_game();

def start_game():
    get_node()

def end_game():
    print('you have reach the end of the game')

start_game()
# Out:
# A
# user_input N
# node A
# user_input N
# B
# B
# user_input N
# node B
# user_input N
# A
# A
# user_input W
# node A
# user_input W
# C
# C
# user_input W
# node C
# user_input W
# D
# D
